# %%
import pandas as pd

# %%
df = pd.read_csv('time_series_covid19_confirmed_global_narrow.csv')

# %%
df.head()
# Out:
#   Province/State Country/Region       Lat      Long        Date  \
# 0     #adm1+name  #country+name  #geo+lat  #geo+lon       #date
# 1            NaN    Afghanistan        33        65  2020-04-14
# 2            NaN    Afghanistan        33        65  2020-04-13
# 3            NaN    Afghanistan        33        65  2020-04-12
# 4            NaN    Afghanistan        33        65  2020-04-11
#
#                           Value ISO 3166-1 Alpha 3-Codes        Region Code  \
# 0  #affected+infected+value+num            #country+code  #region+main+code
# 1                           714                      AFG                142
# 2                           665                      AFG                142
# 3                           607                      AFG                142
# 4                           555                      AFG                142
#
#     Sub-region Code   Intermediate Region Code
# 0  #region+sub+code  #region+intermediate+code
# ...

# %%
countries = df['Country/Region'].values

# %%
len(countries)
# Out:
# 22177

# %%
us = df[df['Country/Region'] == 'US']

# %%
us.sort_values(by='Date')
# Out:
#       Province/State Country/Region      Lat      Long        Date   Value  \
# 21504            NaN             US  37.0902  -95.7129  2020-01-22       1
# 21503            NaN             US  37.0902  -95.7129  2020-01-23       1
# 21502            NaN             US  37.0902  -95.7129  2020-01-24       2
# 21501            NaN             US  37.0902  -95.7129  2020-01-25       2
# 21500            NaN             US  37.0902  -95.7129  2020-01-26       5
# ...              ...            ...      ...       ...         ...     ...
# 21425            NaN             US  37.0902  -95.7129  2020-04-10  496535
# 21424            NaN             US  37.0902  -95.7129  2020-04-11  526396
# 21423            NaN             US  37.0902  -95.7129  2020-04-12  555313
# 21422            NaN             US  37.0902  -95.7129  2020-04-13  580619
# 21421            NaN             US  37.0902  -95.7129  2020-04-14  607670
#
#       ISO 3166-1 Alpha 3-Codes Region Code Sub-region Code  \
# ...

# %%
us_nums = pd.to_numeric(us['Value'])

# %%
us_nums.plot()
